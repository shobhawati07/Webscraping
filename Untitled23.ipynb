# %% [markdown]
# <a href="https://colab.research.google.com/github/shobhawati07/Webscraping/blob/main/Untitled23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
## Create an URL object
url = 'https://www.moneycontrol.com/india/stockmarket/sector-classification/marketstatistics/nse/agri.html'
# Create object page
HEADERS = ({'User-Agent':'', 'Accept-Language': 'en-US, en;q=0.5'})

page = requests.get(url,HEADERS)

# %%
#parser-lxml = Change html to Python friendly format
# Obtain page's information
soup = BeautifulSoup(page.text, 'lxml')

# %%
table=soup.find('table',attrs={'class':"tbldata14 bdrtpg"})

# %%
#tain every title of columns with tag <th>
headers = []
for i in table.find_all('th'):
 title = i.text
 headers.append(title)

# %%
headers
# Out:
# ['Company Name', 'Industry', 'Last Price', 'Change', '%Chg', 'Mkt Cap(Rs cr)']

# %%
mydata = pd.DataFrame(columns = headers)

# %%
# Create a for loop to fill mydata
for j in table.find_all('tr')[1:]:
 row_data = j.find_all('td')
 row = [i.text for i in row_data]
 length = len(mydata)
 mydata.loc[length] = row

# %%
mydata
# Out:
#        Company Name                   Industry Last Price  Change   %Chg  \
# 0      M K Proteins  Vegetable Oils & Products     840.50   64.20   8.27
# 1       Kaveri Seed                Agriculture     605.55   37.05   6.52
# 2        Norben Tea                 Tea/Coffee      11.25    0.50   4.65
# 3    Nath Bio-Genes                Agriculture     223.45    9.55   4.46
# 4   Guj Amb Exports            Food Processing     290.35   10.50   3.75
# ..              ...                        ...        ...     ...    ...
# 64  Rajshree Sugars                      Sugar      56.10   -1.35  -2.35
# 65       ANDHRSUGAR                      Sugar     121.10   -3.45  -2.77
# 66    NK Industries  Vegetable Oils & Products      38.40   -1.40  -3.52
# 67    Bombay Burmah                Agriculture    1215.90  -51.85  -4.09
# 68  SKM Egg Product            Food Processing     444.65  -21.70  -4.65
#
#    Mkt Cap(Rs cr)
# 0           1,052
# 1           3,386
# 2              13
# ...
